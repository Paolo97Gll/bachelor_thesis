# %%
from astropy.io import fits

# %% [markdown]
# # DATA INFO
#
# ## RAW data

# %%
raw = fits.open("../data/HFI/HFI_TOI_143-RAW_R2.00_OD0091.fits")

raw.info()

print("\nTIME")
print(raw["OBT"].columns)

print("\nDATA")
print(raw["143-5"].columns)
# Out:
# Filename: ../data/HFI/HFI_TOI_143-RAW_R2.00_OD0091.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  OBT           1 BinTableHDU     53   12345869R x 2C   [D, B]
#   2  143-1a        1 BinTableHDU     39   12345869R x 1C   [E]
#   3  143-1b        1 BinTableHDU     39   12345869R x 1C   [E]
#   4  143-2a        1 BinTableHDU     39   12345869R x 1C   [E]
#   5  143-2b        1 BinTableHDU     39   12345869R x 1C   [E]
#   6  143-3a        1 BinTableHDU     39   12345869R x 1C   [E]
#   7  143-3b        1 BinTableHDU     39   12345869R x 1C   [E]
#   8  143-4a        1 BinTableHDU     39   12345869R x 1C   [E]
#   9  143-4b        1 BinTableHDU     39   12345869R x 1C   [E]
#  10  143-5         1 BinTableHDU     39   12345869R x 1C   [E]
#  11  143-6         1 BinTableHDU     39   12345869R x 1C   [E]
#  12  143-7         1 BinTableHDU     39   12345869R x 1C   [E]
#
# TIME
# ColDefs(
# ...

# %% [markdown]
# ## SCI data

# %%
sci = fits.open("../data/HFI/HFI_TOI_143-SCI_R2.00_OD0091.fits")

sci.info()

print("\nTIME")
print(sci["OBT"].columns)

print("\nDATA")
print(sci["143-5"].columns)
# Out:
# Filename: ../data/HFI/HFI_TOI_143-SCI_R2.00_OD0091.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  OBT           1 BinTableHDU     53   12345869R x 2C   [D, B]
#   2  143-5         1 BinTableHDU     65   12345869R x 2C   [E, B]
#   3  143-6         1 BinTableHDU     65   12345869R x 2C   [E, B]
#   4  143-7         1 BinTableHDU     65   12345869R x 2C   [E, B]
#
# TIME
# ColDefs(
#     name = 'OBT'; format = 'D'; unit = '2^-16 s'
#     name = 'FLAG'; format = 'B'; unit = 'none'
# )
#
# DATA
# ColDefs(
#     name = 'SIGNAL'; format = 'E'; unit = 'Kcmb'
#     name = 'FLAG'; format = 'B'; unit = 'none'
# )

# %% [markdown]
# # TEST

# %%
import numpy.random as rnd

sx = int(rnd.random()*1000000)
dx = sx + 100

import matplotlib.pyplot as plt

plt.subplot(211)
plt.plot( raw["OBT"].data[sx:dx]["OBT"] , raw["143-5"].data[sx:dx] )

plt.subplot(212)
plt.plot( sci["OBT"].data[sx:dx]["OBT"] , sci["143-5"].data[sx:dx]["SIGNAL"] )

plt.show()

# %%
abs(raw["143-5"].data[sx:dx].field(0))
# Out:
# array([1.8378440e-06, 1.9688262e-06, 1.9538179e-06, 1.9620043e-06,
#        1.8487592e-06, 1.7641665e-06, 1.9183435e-06, 2.0684272e-06,
#        1.8460304e-06, 1.7819037e-06, 2.0138514e-06, 1.8473949e-06,
#        1.6577435e-06, 2.1339183e-06, 2.0370462e-06, 2.1257320e-06,
#        1.8542169e-06, 2.0766138e-06, 1.9579111e-06, 2.1502913e-06,
#        1.9538179e-06, 2.2035026e-06, 2.0302241e-06, 2.1270964e-06,
#        1.8583100e-06, 2.0684272e-06, 1.9060640e-06, 2.0247664e-06,
#        1.7723529e-06, 2.2703582e-06, 1.7191414e-06, 1.9524534e-06,
#        1.7341498e-06, 1.9442671e-06, 1.7928189e-06, 1.9551824e-06,
#        1.7764461e-06, 2.0288599e-06, 1.8337508e-06, 2.2035026e-06,
#        2.0302241e-06, 2.0056650e-06, 2.2198756e-06, 1.8869623e-06,
#        1.9060640e-06, 2.1448336e-06, 2.0138514e-06, 1.8473949e-06,
#        2.0206733e-06, 2.1339183e-06, 1.9770125e-06, 2.0643340e-06,
#        2.2171466e-06, 1.9551824e-06, 2.0193090e-06, 2.1502913e-06,
# ...
